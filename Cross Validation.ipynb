# %%
import pandas as pd
data = pd.read_csv("iris.csv")
data = data.drop("Id",axis=1)
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = data.drop("Species",axis=1)
x.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
data.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
y = data["Species"]

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %% [raw]
# data.info()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
#check all algorithms

# %% [raw]
# K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test,y_test)
# Out:
# 0.9555555555555556

# %% [raw]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %% [raw]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb= GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
nb.score(x_test,y_test)
# Out:
# 0.9777777777777777

# %% [raw]
# Support Vector Machine

# %%
from sklearn.svm import SVC
svm= SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.8888888888888888

# %%
#After enter again and again Accuracy count get to different values.

# %%
#Reason = model get random values again and again

# %%
#Sollution = Use Cross Validation to All of the Algorithms and get only one accuracy value for one algorithm

# %%
#from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
#NOT USE THIS LINE

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
cross_val_score(knn, x, y, cv=5).mean()
#cv=cross validation
# Out:
# 0.9733333333333334

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()
cross_val_score(rf, x, y, cv=5).mean()
# Out:
# 0.9466666666666667

# %%
from sklearn.naive_bayes import GaussianNB
nb= GaussianNB()
cross_val_score(nb, x, y, cv=5).mean()
# Out:
# 0.9533333333333334

# %%
from sklearn.svm import SVC
svm= SVC()
cross_val_score(svm, x, y, cv=5).mean()
# Out:
# 0.9666666666666666
